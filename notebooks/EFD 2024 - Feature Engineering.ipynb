# %% [markdown]
# # **Edmonton Food Drive 2024 - Feature Engineering**

# %% [markdown]
# ## **Introduction**
# The Edmonton Food Drive is a collaborative initiative designed to tackle food insecurity in Edmonton. This drive ​mobilizes volunteers and resources to collect and distribute food to those in need. By leveraging machine learning, ​the project aims to enhance operational efficiency and maximize the impact of each donation. The integration of ​real-time data and optimized routing will contribute to a more streamlined and effective food distribution process.
#
# **Team Name:** Team 404
#
# **Team Members:**
# *   Catrina Llamas
# *   Roe Joshua Alincastre
# *   Kendrick Moreno

# %% [markdown]
# #### **Task 1: Imports and data loading**
# Now lets import required libraries that we are going to use throughout this project.

# %%
import os
import yaml
import numpy as np
import pandas as pd
import sys
import warnings
warnings.filterwarnings("ignore")

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))
from utils.open_config import load_config
from preprocess import FeatureEngineer

# %% [markdown]
# ##### **Load the dataset**
# We are going to load the cleaned dataset.

# %%
params, project_root = load_config()
base_path = project_root
df_efd_cleaned = pd.read_csv(os.path.join(base_path, params["files"]["cleaned_data"]))
df_efd_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             1045 non-null   int64
#  1   Unnamed: 0               1045 non-null   int64
#  2   Drop Off Location        1045 non-null   object
#  3   Stake                    1045 non-null   object
#  4   Route Information        1045 non-null   object
#  5   Time Spent               1045 non-null   int64
#  6   Total Adult Volunteers   1045 non-null   float64
#  7   Total Youth Volunteers   1045 non-null   float64
#  8   Number of Doors          1045 non-null   float64
#  9   Number of Donation Bags  1045 non-null   float64
#  10  Number of Routes         1045 non-null   float64
#  11  Ward                     1045 non-null   object
#  12  Year                     1045 non-null   int64
#  13  Latitude                 1041 non-null   float64
#  14  Longitude                1041 non-null   float64
#  15  Total Volunteers         1045 non-null   float64
#  16  Donation Bags per Door   1045 non-null   float64
#  17  Donation Bags per Route  1045 non-null   float64
# dtypes: float64(10), int64(4), object(4)
# memory usage: 147.1+ KB

# %% [markdown]
# #### **Task 1: Feature Engineering**
#
# Now lets introduced 3 new fields.
# *   Total Volunteers
# *   Donation Bags per Door
# *   Donation Bags per Route

# %%
feature_engineer = FeatureEngineer(df_efd_cleaned)
df_efd_cleaned = feature_engineer.feature_engineering()
df_efd_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             1045 non-null   int64
#  1   Unnamed: 0               1045 non-null   int64
#  2   Drop Off Location        1045 non-null   object
#  3   Stake                    1045 non-null   object
#  4   Route Information        1045 non-null   object
#  5   Time Spent               1045 non-null   int64
#  6   Total Adult Volunteers   1045 non-null   float64
#  7   Total Youth Volunteers   1045 non-null   float64
#  8   Number of Doors          1045 non-null   float64
#  9   Number of Donation Bags  1045 non-null   float64
#  10  Number of Routes         1045 non-null   float64
#  11  Ward                     1045 non-null   object
#  12  Year                     1045 non-null   int64
#  13  Latitude                 1041 non-null   float64
#  14  Longitude                1041 non-null   float64
#  15  Total Volunteers         1045 non-null   float64
#  16  Donation Bags per Door   1045 non-null   float64
#  17  Donation Bags per Route  1045 non-null   float64
# dtypes: float64(10), int64(4), object(4)
# memory usage: 147.1+ KB

# %%
df_efd_cleaned
# Out:
#       Unnamed: 0.1  Unnamed: 0                    Drop Off Location  \
# 0                0           0                      Bearspaw Chapel
# 1                1           1                      Bearspaw Chapel
# 2                2           2                   Londonberry Chapel
# 3                3           3                Gateway Stake Centre
# 4                4           4             Bonnie Doon Stake Centre
# ...            ...         ...                                  ...
# 1040          1040        1050                               Onoway
# 1041          1041        1051                   North Stake Centre
# 1042          1042        1053  Parkland (Spruce Grove/Stony Plain)
# 1043          1043        1054                   North Stake Centre
# 1044          1044        1055                   Londonderry Chapel
#
#                      Stake Route Information  Time Spent  \
# 0          Riverbend Stake         Route 676          15
# 1            Gateway Stake           Route 0          15
# 2        Bonnie Doon Stake     Route Unknown          15
# 3            Gateway Stake          Route 50          15
# 4        Bonnie Doon Stake          Route 98          15
# ...                    ...               ...         ...
# 1040  Edmonton North Stake     Route Unknown          45
# 1041  Edmonton North Stake     Route Unknown          45
# 1042  Edmonton North Stake     Route Unknown         120
# 1043  Edmonton North Stake     Route Unknown         150
# 1044  Edmonton North Stake     Route Unknown          30
#
#       Total Adult Volunteers  Total Youth Volunteers  Number of Doors  \
# 0                        7.0                     7.0             78.0
# 1                        0.0                     0.0              0.0
# 2                        1.0                     0.0              1.0
# 3                        2.0                     2.0             20.0
# 4                        2.0                     2.0             20.0
# ...                      ...                     ...              ...
# 1040                     2.0                     0.0            195.0
# 1041                     2.0                     0.0            150.0
# 1042                     2.0                     4.0            195.0
# 1043                     2.0                     0.0            600.0
# 1044                     2.0                     2.0            195.0
#
#       Number of Donation Bags  Number of Routes                    Ward  Year  \
# 0                       599.0               1.0           Woodbend Ward  2024
# 1                         0.0               1.0          Lee Ridge Ward  2024
# 2                         1.0               1.0          Clareview Ward  2024
# 3                        20.0               1.0          Lee Ridge Ward  2024
# 4                        15.0               1.0     Forest Heights Ward  2024
# ...                       ...               ...                     ...   ...
# 1040                     10.0               2.0             Onoway Ward  2023
# 1041                     20.0               2.0              Namao Ward  2023
# 1042                     51.0               2.0        Stony Plain Ward  2023
# 1043                     78.0               3.0          Griesbach Ward  2023
# 1044                      5.0               2.0  Lago Lindo Branch Ward  2023
#
#        Latitude   Longitude  Total Volunteers  Donation Bags per Door  \
# 0     53.474700 -113.639900              14.0                7.679487
# 1     53.469593 -113.444355               0.0                0.000000
# 2     53.595400 -113.415300               1.0                1.000000
# 3     53.469593 -113.444355               4.0                1.000000
# 4     53.544537 -113.451250               4.0                0.750000
# ...         ...         ...               ...                     ...
# 1040  53.703000 -114.197300               2.0                0.051282
# 1041  53.724200 -113.479900               2.0                0.133333
# 1042  53.528600 -114.010300               6.0                0.261538
# 1043  53.606808 -113.504229               2.0                0.130000
# 1044  53.615900 -113.486700               4.0                0.025641
#
#       Donation Bags per Route
# 0                       599.0
# 1                         0.0
# 2                         1.0
# 3                        20.0
# 4                        15.0
# ...                       ...
# 1040                      5.0
# 1041                     10.0
# 1042                     25.5
# 1043                     26.0
# 1044                      2.5
#
# [1045 rows x 18 columns]

# %% [markdown]
# Now, let's save the file in a csv file.

# %%
df_efd_cleaned.to_csv(os.path.join(base_path, params["files"]["cleaned_data"]))
